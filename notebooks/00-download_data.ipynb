# %%
import pandas as pd

# %%
#ler os dados do repositorio pela url
df = pd.read_csv('https://raw.githubusercontent.com/atlantico-academy/datasets/refs/heads/main/titanic.csv')
#salvar na pasta raw
df = df.to_csv('../data/raw/titanic.csv')

# %%
#dicionarios de dados
#survived,pclass,sex,age,sibsp,parch,fare,embarked,class,who,adult_male,deck,embark_town,alive,alone
data_dictionary = pd.DataFrame([
    {
        'variavel': 'survived',
        'descrição': 'Sobreviventes da tragédia',
        'tipo':'quantitativo',
        'subtipo':'discreto',
    },
    {
        'variavel': 'pclass',
        'descrição': 'Status socioeconomico',
        'tipo':'qualitativo',
        'subtipo':'ordinal',
    },
    {
        'variavel': 'sex',
        'descrição': 'Gênero das pessoas',
        'tipo':'qualitativo',
        'subtipo':'Nominal',
    },
    {
        'variavel': 'age',
        'descrição': 'Idade das pessoas',
        'tipo':'quantitativa',
        'subtipo':'continua',
    },
    {
        'variavel': 'sibsp',
        'descrição': 'Relação familiar de irmãos e cônjuge ',
        'tipo':'qualitativas ',
        'subtipo':'nominal',
    },
    {
        'variavel': 'parch',
        'descrição': 'Relação familiar de pais e filhos',
        'tipo':'qualitativas ',
        'subtipo':'nominal',
    },
    {
        'variavel': 'fare',
        'descrição': 'Tarifa do passageiro',
        'tipo':'quantitativo',
        'subtipo':'continua',
    },
    {
        'variavel': 'embarked',
        'descrição': 'Porto de embarcação',
        'tipo':'quantitativa',
        'subtipo':'continua',
    },
    {
        'variavel': 'class',
        'descrição': 'Número da classe social',
        'tipo':'quantitativa',
        'subtipo':'discreto',
    },
    {
        'variavel': 'who',
        'descrição': 'Homem ou Mulher',
        'tipo':'qualitativa',
        'subtipo':'nominal',
    },
    {
        'variavel': 'adult_male',
        'descrição': 'Homens adultos',
        'tipo':'quantitativa',
        'subtipo':'discreto',
    },
    {
        'variavel': 'deck',
        'descrição': 'convés',
        'tipo':'qualitativa',
        'subtipo':'Nominal',
    },
    {
        'variavel': 'embark_town',
        'descrição': 'Cidade de embarcação',
        'tipo':'quantitativa',
        'subtipo':'discreto',
    },
    {
        'variavel': 'alive',
        'descrição': 'Pessoas vivas',
        'tipo':'quantitativa',
        'subtipo':'discreto', 
    },
    {
        'variavel': 'alone',
        'descrição': 'Pessoas sozinhas',
        'tipo':'quantitativa',
        'subtipo':'discreto',
    }

])

#salvar
data_dictionary.to_csv("../data/external/dictionario.csv")
