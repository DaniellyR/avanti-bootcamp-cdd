# %%
import pandas as pd

# %%
#ler os dados do repositorio pela url
df = pd.read_csv('https://raw.githubusercontent.com/atlantico-academy/datasets/refs/heads/main/titanic.csv')
#salvar na pasta raw
df = df.to_csv('../data/raw/titanic.csv')

# %%
#dicionarios de dados
#survived,pclass,sex,age,sibsp,parch,fare,embarked,class,who,adult_male,deck,embark_town,alive,alone
data_dictionary = pd.DataFrame([
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'', 
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':'',
    },
    {
        'variavel': '',
        'descrição': '',
        'tipo':'',
        'subtipo':''
    }

])

#salvar
data_dictinary.to_csv ("xxx")
# Out:
#   Cell In[3], line 4
#     'variavel': = '',
#                 ^
# SyntaxError: invalid syntax
